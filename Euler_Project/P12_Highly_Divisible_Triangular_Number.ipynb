# %% [markdown]
# # Highly Divisible Triangular Number

# %% [markdown]
# The sequence of triangle numbers is generated by adding the natural numbers. So the $7$<sup>th</sup> triangle number would be $1 + 2 + 3 + 4 + 5 + 6 + 7 = 28$. The first ten terms would be:
# $$1, 3, 6, 10, 15, 21, 28, 36, 45, 55, \dots$$
# Let us list the factors of the first seven triangle numbers:
# \begin{align}
# \mathbf 1 & \colon 1\\
# \mathbf 3 & \colon 1,3\\
# \mathbf 6 & \colon 1,2,3,6\\
# \mathbf{10} & \colon 1,2,5,10\\
# \mathbf{15} & \colon 1,3,5,15\\
# \mathbf{21} & \colon 1,3,7,21\\
# \mathbf{28} & \colon 1,2,4,7,14,28
# \end{align}
# We can see that $28$ is the first triangle number to have over five divisors.
# What is the value of the first triangle number to have over five hundred divisors?

# %%
def Triangular_number(n):
    return n*(n+1)//2

# %%
for i in range(1,8):
    print(Triangular_number(i))
# Out:
# 1
# 3
# 6
# 10
# 15
# 21
# 28

# %%
import math

def Factors(n):
    count = 0
    root = int(math.sqrt(n))
    for i in range(1, root + 1):
        if n % i == 0:
            count += 2
    if root * root == n:  # Correcting the count for perfect square
        count -= 1
    return count

# %%
Factors(28)
# Out:
# 6

# %%
def find_triangle_number(limit):
    n = 1
    while True:
        # Generate the nth triangle number
        tri_number = Triangular_number(n)
        # Count the number of divisors
        # We use a small trick here: n and n+1 are coprime, their GCD is 1
        if n % 2 == 0:
            divisors = Factors(n // 2) * Factors(n + 1)
        else:
            divisors = Factors(n) * Factors((n + 1) // 2)

        # Check if it meets the condition
        if divisors > limit:
            return tri_number

        n += 1

# %%
find_triangle_number(500)
# Out:
# 76576500
